# %% [markdown]
# Importing the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# Importing the dataset

# %%
df = pd.read_csv('Position_Salaries.csv')
x = df.iloc[:, 1:-1].values
y = df.iloc[:, -1].values

# %% [markdown]
# Training the Linear Regression model on the whole dataset

# %%
from sklearn.linear_model import LinearRegression

linear_regressor = LinearRegression()
linear_regressor.fit(x, y)
linear_pred_results = linear_regressor.predict(x)

# %% [markdown]
# Training the Polynomial Regression model on the whole dataset

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_regressor = PolynomialFeatures(degree = 2)
x_poly = poly_regressor.fit_transform(x)
linear_regressor_2 = LinearRegression()
linear_regressor_2.fit(x_poly, y)
poly_pred_results =

# %% [markdown]
# Visualizing the Linear Regression results

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, linear_pred_results, color = 'blue')
plt.title('Linear Regression results for Position Salaries')
plt.xlabel('Years of Experience')
plt.xlabel('Salary')
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Visualizing the Polynomial Regression results

# %% [markdown]
# Visualizing the Polynomial Regression results (for higher resolution and a smoother curve)

# %% [markdown]
# Predicting a new result with Linear Regression

# %% [markdown]
# Predicting a new result with Polynomial Regression
